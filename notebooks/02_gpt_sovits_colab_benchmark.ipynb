# %% [markdown]
# # LAPQUE Personal Vietnamese TTS — GPT-SoVITS Benchmark on Google Colab (Free T4 GPU)
# Thực thi tổng hợp 20 câu kiểm thử tiếng Việt chuẩn trên GPT-SoVITS đối chứng với F5-TTS (0 đồng).

# %%
# Bước 1: Clone upstream repo và cài đặt requirements
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git
# %cd GPT-SoVITS
# !pip install --quiet -r requirements.txt

# %%
# Bước 2: Kiểm tra GPU
# !nvidia-smi

# %%
# Bước 3: Chạy tổng hợp 20 câu benchmark đối chứng
# !python 02_gpt_sovits_colab_benchmark.py ref_sample.wav
