# %% [markdown]
# # LAPQUE Personal Vietnamese TTS — F5-TTS Fine-Tuning on Google Colab (Free T4 GPU)
# Huấn luyện tinh chỉnh F5-TTS trên giọng nói cá nhân của bạn với chi phí 0 đồng.

# %%
# Bước 1: Cài đặt môi trường huấn luyện
# !pip install --quiet torch torchaudio soundfile librosa git+https://github.com/SWivid/F5-TTS.git accelerate wandb

# %%
# Bước 2: Tải script fine-tuning và phân tách tập Train/Val (85/15)
# !python 03_f5_tts_finetuning_colab.py metadata.csv
