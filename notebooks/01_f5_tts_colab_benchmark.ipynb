# %% [markdown]
# # LAPQUE Personal Vietnamese TTS — F5-TTS Benchmark on Google Colab (Free T4 GPU)
# Thực thi tổng hợp 20 câu kiểm thử tiếng Việt chuẩn trên F5-TTS với chi phí 0 đồng.

# %%
# Bước 1: Cài đặt thư viện F5-TTS và dependencies
# !pip install --quiet torch torchaudio soundfile librosa git+https://github.com/SWivid/F5-TTS.git cached_path

# %%
# Bước 2: Tải script benchmark chuẩn từ dự án và thực thi
import urllib.request
print("Environment ready. GPU Check:")
# !nvidia-smi

# %%
# Bước 3: Chạy tổng hợp 20 câu benchmark
# Đặt file ghi âm mẫu ref_sample.wav vào thư mục Colab
# !python 01_f5_tts_colab_benchmark.py ref_sample.wav
